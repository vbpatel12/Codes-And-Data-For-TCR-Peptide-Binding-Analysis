# %%
import os
import random
import shutil
import pandas as pd
import openpyxl as xl
import numpy as np
import math

# change directory
# os.chdir(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary')

# %%
def category(dist):
    """
    The category of distance.
    """
    if dist < 0.5:
        cate = "<0.5"
    if dist <=1.2:
        cate = "1.2"
    elif dist >= 1 and dist < 1.5:
        cate = "[1, 1.5]"
    elif dist >= 1.5 and dist < 3:
        cate = "[1.5, 3]"
    elif dist >= 3 and dist < 5:
        cate = "[3, 5]"
    else:
        cate = ">=5"
    return cate

def distance_calculate2(pdb_name, lines, outfile):
    """
    Calculate the distance between atoms.
    """
    # carbons = ["CA ","CB ","CG ","CD ","CE ","CZ ","CH ","CD1","CD2","CG1","CG2","CE1","CE2","CE3","CZ1","CZ2","CH1","CH2"]
    atom_name = []
    chain_name = []
    res_name = []
    res_num = []
    x_coord = []
    y_coord =[]
    z_coord =[]
    for line in lines:
        if line.startswith('ATOM'):
            atom_name.append(str(line[13:16]))
            chain_name.append(str(line[21:22]))
            res_name.append(str(line[17:20]))
            res_num.append(int(line[23:26]))
            x_coord.append(float(line[31:38]))
            y_coord.append(float(line[39:46]))
            z_coord.append(float(line[47:54]))

    output = []
    a = 0
    # Added column: peptide name
    for i in range(0, len(x_coord), 1):
        for j in range(i+1, len(x_coord), 1):
            if chain_name [i] == "A" and chain_name[j] == "D" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration
                
                     
            if chain_name [i] == "B"  and chain_name[j] == "D" :
                 if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration

                    
            if chain_name [i] == "C"   and chain_name[j] == "D" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration
            if chain_name [i] == "D" and chain_name[j] == "E" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                       StopIteration

    
    # pd.DataFrame(res, columns=columns).to_excel(file_name3, index=None)       
    output = np.array(output)
    if len(output) ==0:
        outfile.write( file +' has no clash  \n')
    else:
        outfile.write(file + ' has '+ str(len(output)) +' clash   \n')
        return output

# %%
# Clash Distance calculation for CDR3 beta loop
wb = xl.load_workbook('/Users/vinipatel/Desktop/lab2/CDR3_loops/AddProt_Master.xlsx', data_only = True)
sheet = wb['clas_dis']
# using for loop- assign variable to each cells of different columns
for row in range(2, sheet.max_row + 1):    
    cell2 = sheet.cell(row, 2)    
    cell3 = sheet.cell(row, 3)    
    sequence = cell3.value    
    pdb_names = cell2.value       
    file_names = str(pdb_names)
    Clash_dist_file = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/' +file_names+ 'CDR3a_clash_dist'
    new_path = os.path.join(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/', Clash_dist_file)
    os.mkdir(new_path)
    print(Clash_dist_file)
      
    CDR3_file = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/' +file_names+ 'CDR3a_vary_loop'
    os.chdir(CDR3_file)
    print(CDR3_file)
    files = os.listdir(CDR3_file)
    outfile = 'Clash_dist_list.txt'
    with open (outfile ,'w') as f:
        for file in files:
    # print(file)
            if file.endswith('.pdb'):
                src = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/' +file_names + 'CDR3a_vary_loop/' + file
                print(src)
                pdb_name = src
                input_file = src 
                with open(input_file,'r') as pdb_file:
                    lines = pdb_file.readlines()
                
                file_name3 = file + "_CDR3_distance.xlsx"
                res = distance_calculate2(pdb_name, lines, f)
                columns = [ "atom name i", "chain name i", "res name i", "res num i", "atom name j", "chain name j", "res name j", "res num j", "distance", "distance category"] 
                pd.DataFrame(res, columns=columns).to_excel(file_name3, index=None)
                shutil.move(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/' +file_names + 'CDR3a_vary_loop/' + file_name3, Clash_dist_file)
                
    f.close()
    shutil.move(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3a_loop_vary/' +file_names+ 'CDR3a_vary_loop/Clash_dist_list.txt', Clash_dist_file)

# %%
# Clash Distance calculation for CDR3 beta loop
def category(dist):
    """
    The category of distance.
    """
    if dist < 0.5:
        cate = "<0.5"
    if dist <=1.2:
        cate = "1.2"
    elif dist >= 1 and dist < 1.5:
        cate = "[1, 1.5]"
    elif dist >= 1.5 and dist < 3:
        cate = "[1.5, 3]"
    elif dist >= 3 and dist < 5:
        cate = "[3, 5]"
    else:
        cate = ">=5"
    return cate

def distance_calculate2(pdb_name, lines, outfile):
    """
    Calculate the distance between atoms.
    """
    # carbons = ["CA ","CB ","CG ","CD ","CE ","CZ ","CH ","CD1","CD2","CG1","CG2","CE1","CE2","CE3","CZ1","CZ2","CH1","CH2"]
    atom_name = []
    chain_name = []
    res_name = []
    res_num = []
    x_coord = []
    y_coord =[]
    z_coord =[]
    for line in lines:
        if line.startswith('ATOM'):
            atom_name.append(str(line[13:16]))
            chain_name.append(str(line[21:22]))
            res_name.append(str(line[17:20]))
            res_num.append(int(line[23:26]))
            x_coord.append(float(line[31:38]))
            y_coord.append(float(line[39:46]))
            z_coord.append(float(line[47:54]))

    output = []
    a = 0
    # Added column: peptide name
    for i in range(0, len(x_coord), 1):
        for j in range(i+1, len(x_coord), 1):
            if chain_name [i] == "A" and chain_name[j] == "E" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration
                
                     
            if chain_name [i] == "B"  and chain_name[j] == "E" :
                 if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration

                    
            if chain_name [i] == "C"   and chain_name[j] == "E" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                        StopIteration
            if chain_name [i] == "D" and chain_name[j] == "E" :
                if res_num[i] != res_num[j] or res_num[i] == res_num[j]:
                    xx = (x_coord[i]-x_coord[j])**2
                    yy = (y_coord[i]-y_coord[j])**2
                    zz = (z_coord[i]-z_coord[j])**2
                    dist = math.sqrt(xx+yy+zz)
                    if dist <=1.2:
                    # clash_dist = dist
                    # print(clash_dist)
                        cate = category(dist)
                        output.append([ atom_name[i], chain_name[i], res_name[i], res_num[i], atom_name[j], chain_name[j], res_name[j], res_num[j], float(dist), cate])
                    
                    else:
                       StopIteration

    
    # pd.DataFrame(res, columns=columns).to_excel(file_name3, index=None)       
    output = np.array(output)
    if len(output) ==0:
        outfile.write( file +' has no clash  \n')
    else:
        outfile.write(file + ' has '+ str(len(output)) +' clash   \n')
        return output

# %%
# Clash Distance calculation excel sheet formation for CDR3 beta loop
wb = xl.load_workbook('/Users/vinipatel/Desktop/lab2/CDR3_loops/AddProt_Master.xlsx', data_only = True)
sheet = wb['clas_dis']
# using for loop- assign variable to each cells of different columns
for row in range(2, sheet.max_row + 1):    
    cell2 = sheet.cell(row, 2)    
    cell3 = sheet.cell(row, 3)    
    sequence = cell3.value    
    pdb_names = cell2.value       
    file_names = str(pdb_names)
    Clash_dist_file = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/' +file_names+ 'CDR3b_clash_dist'
    new_path = os.path.join(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/', Clash_dist_file)
    os.mkdir(new_path)
    print(Clash_dist_file)
      
    CDR3_file = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/' +file_names+ 'CDR3b_vary_loop'
    os.chdir(CDR3_file)
    print(CDR3_file)
    files = os.listdir(CDR3_file)
    outfile = 'Clash_dist_list.txt'
    with open (outfile ,'w') as f:
        for file in files:
    # print(file)
            if file.endswith('.pdb'):
                src = r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/' +file_names + 'CDR3b_vary_loop/' + file
                print(src)
                pdb_name = src
                input_file = src 
                with open(input_file,'r') as pdb_file:
                    lines = pdb_file.readlines()
                
                file_name3 = file + "_CDR3_distance.xlsx"
                res = distance_calculate2(pdb_name, lines, f)
                columns = [ "atom name i", "chain name i", "res name i", "res num i", "atom name j", "chain name j", "res name j", "res num j", "distance", "distance category"] 
                pd.DataFrame(res, columns=columns).to_excel(file_name3, index=None)
                shutil.move(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/' +file_names + 'CDR3b_vary_loop/' + file_name3, Clash_dist_file)
                
    f.close()
    shutil.move(r'/Users/vinipatel/Desktop/lab2/CDR3_loops/CDR3b_loop_vary/' +file_names+ 'CDR3b_vary_loop/Clash_dist_list.txt', Clash_dist_file)
